# %%
import pandas

# %%
df=pandas.read_csv("./example.csv")
df
# Out:
#            Continent          Country
# 0             Europe   United Kingdom
# 1             Europe           Russia
# 2             Europe            Italy
# 3             Europe           France
# 4             Europe          Belgium
# 5             Europe          Denmark
# 6             Europe           Sweden
# 7             Europe          Estonia
# 8             Europe           Greece
# 9             Europe           Latvia
# 10            Europe      Switzerland
# 11            Europe           Poland
# 12            Europe        Lithuania
# 13            Europe          Hungary
# 14            Europe          Romania
# 15            Europe            Spain
# 16            Europe          Germany
# 17            Europe          Finland
# 18            Europe           Norway
# 19            Europe          Ireland
# 20            Europe         Slovakia
# 21            Europe         Portugal
# 22            Europe          Austria
# 23            Europe          Iceland
# ...
